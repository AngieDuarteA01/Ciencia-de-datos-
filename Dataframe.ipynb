# %%
import numpy as np
import pandas as pd

# %%
#Convertir de lista a dataframe
ventas=pd.Series([22,15,70])
ventas
# Out:
# 0    22
# 1    15
# 2    70
# dtype: int64

# %%
ventas=pd.Series([22,15,70],index=["Enero","Febreo","Marzo"])
ventas
# Out:
# Enero     22
# Febreo    15
# Marzo     70
# dtype: int64

# %%
ventas[0]
# Out:
# <ipython-input-4-eacc5df2ea8a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ventas[0]
# 22

# %%
ventas["Enero"]
# Out:
# 22

# %%
ventas.dtype
#cuando haya errores
# Out:
# dtype('int64')

# %%
#para visualizacion de features
ventas.index
# Out:
# Index(['Enero', 'Febreo', 'Marzo'], dtype='object')

# %%
#para obtener los valores de la feature
ventas.values
# Out:
# array([22, 15, 70])

# %%
ventas.name="Ventas 2025"
ventas
# Out:
# Enero     22
# Febreo    15
# Marzo     70
# Name: Ventas 2025, dtype: int64

# %%
ventas.index.name="Meses"
ventas
# Out:
# Meses
# Enero     22
# Febreo    15
# Marzo     70
# Name: Ventas 2025, dtype: int64

# %% [markdown]
# Diccionarios
# 1.No tienen indexación
# 2.Poseen una clve unica , y un valor asociado a la clave
# 3.Son mutables

# %%
diccionario={"Enero":22,"Febrero":15,"Marzo":70}
type(diccionario)
# Out:
# dict

# %%
ventas1=pd.Series(diccionario)
ventas1
# Out:
# Enero      22
# Febrero    15
# Marzo      70
# dtype: int64

# %%
alex=pd.Series(diccionario,index=["Enero","Febrero","Marzo","Abril"])
alex
# Out:
# Enero      22.0
# Febrero    15.0
# Marzo      70.0
# Abril       NaN
# dtype: float64

# %%
medidas=pd.DataFrame({
    "Humedad":[41,20,30,80],
    "Salinidad":[22,15,30,80],
    "Sensórica":["si","no","no","no"],
    "Acidez":["alta","media","baja", "baja"],
    "PH":[1,7,14,13]},
  index=["La ureña", "Paso chico","la laguna", "los teres "]
                     )
medidas
# Out:
#             Humedad  Salinidad Sensórica Acidez  PH
# La ureña         41         22        si   alta   1
# Paso chico       20         15        no  media   7
# la laguna        30         30        no   baja  14
# los teres        80         80        no   baja  13

# %%
medidas.index.name="veredas"

# %%
medidas.Acidez
# Out:
# veredas
# La ureña       alta
# Paso chico    media
# la laguna      baja
# los teres      baja
# Name: Acidez, dtype: object

# %%
medidas[["PH","Acidez"]]
# Out:
#             PH Acidez
# veredas
# La ureña     1   alta
# Paso chico   7  media
# la laguna   14   baja
# los teres   13   baja

# %%
#Nombre de filas y columnas
medidas.axes
# Out:
# [Index(['La ureña', 'Paso chico', 'la laguna', 'los teres '], dtype='object', name='veredas'),
#  Index(['Humedad', 'Salinidad', 'Sensórica', 'Acidez', 'PH'], dtype='object')]

# %%
medidas.shape
# Out:
# (4, 5)

# %%
###Ejercicios
dados los diccionarios convertir a datagramas y usar todos los métodos aprendidos :
elementos={"número atómico":[1,6,46,88],
           "Masa atómica":[1,12,107,226],
           "Famila":["no metal","no ,no metal","metal","metal"]}

# %%
Elementos=pd.DataFrame({
    "número atómico":[1,6,46,88],
    "Masa atómica":[1,12,107,226],
    "Famila":["no metal","no metal","metal","metal"],
  },
  index=["E1", "E2","E3", "E4"]
                     )
Elementos
# Out:
#     número atómico  Masa atómica    Famila
# E1               1             1  no metal
# E2               6            12  no metal
# E3              46           107     metal
# E4              88           226     metal

# %%
#Convertir en dataframe el siguiente conjunto de medidas
medida_2020={"Ag":2,"Au":5,"Cu":3,"Pt":2}
medida_2021={"Ag":4,"Au":3,"Cu":6,"Pt":1}
medida_2022={"Ag":8,"Au":2,"Cu":15,"Pt":0}
medida_2023={"Ag":5,"Au":1,"Cu":0,"Pt":5}
medida_2024={"Ag":7,"Au":0,"Cu":3,"Pt":2}
medida_2025={"Ag":9,"Au":1,"Cu":3,"Pt":5}

# %%
MEDIDA=pd.DataFrame({
    "AG":[2,4,8,5,7,9],
    "AU":[5,3,2,1,0,1],
    "CU":[3,6,15,0,3,3],
    "PT":[2,1,0,5,2,5]
},
  index=["2020", "2021","2022", "2023","2024","2025"]
                     )
MEDIDA
MEDIDA
# Out:
#       AG  AU  CU  PT
# 2020   2   5   3   2
# 2021   4   3   6   1
# 2022   8   2  15   0
# 2023   5   1   0   5
# 2024   7   0   3   2
# 2025   9   1   3   5

# %%
MEDIDA.shape
# Out:
# (6, 4)

# %%
MEDIDA[["AG","PT"]]
# Out:
#       AG  PT
# 2020   2   2
# 2021   4   1
# 2022   8   0
# 2023   5   5
# 2024   7   2
# 2025   9   5

# %%
MEDIDA.columns
# Out:
# Index(['AG', 'AU', 'CU', 'PT'], dtype='object')

# %%
MEDIDA.dtypes
# Out:
# AG    int64
# AU    int64
# CU    int64
# PT    int64
# dtype: object
